# %% [markdown]
# ## Import Necessary Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Load The Dataset And Make A Copy

# %%
raw_data = pd.read_csv('Downloads/mental-illnesses-prevalence.csv')
raw_data
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6415     Zimbabwe  ZWE  2015
# 6416     Zimbabwe  ZWE  2016
# 6417     Zimbabwe  ZWE  2017
# 6418     Zimbabwe  ZWE  2018
# 6419     Zimbabwe  ZWE  2019
#
#       Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                              0.223206
# 1                                              0.222454
# 2                                              0.221751
# 3                                              0.220987
# 4                                              0.220183
# ...                                                 ...
# 6415                                           0.201042
# 6416                                           0.201319
# 6417                                           0.201639
# ...

# %%
mh_data = raw_data.copy()
mh_data
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6415     Zimbabwe  ZWE  2015
# 6416     Zimbabwe  ZWE  2016
# 6417     Zimbabwe  ZWE  2017
# 6418     Zimbabwe  ZWE  2018
# 6419     Zimbabwe  ZWE  2019
#
#       Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                              0.223206
# 1                                              0.222454
# 2                                              0.221751
# 3                                              0.220987
# 4                                              0.220183
# ...                                                 ...
# 6415                                           0.201042
# 6416                                           0.201319
# 6417                                           0.201639
# ...

# %%
pd.isnull(mh_data).count()
# Out:
# Entity                                                                               6420
# Code                                                                                 6420
# Year                                                                                 6420
# Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized    6420
# Depressive disorders (share of population) - Sex: Both - Age: Age-standardized       6420
# Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized          6420
# Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized          6420
# Eating disorders (share of population) - Sex: Both - Age: Age-standardized           6420
# dtype: int64

# %%
mh_data.rename(columns = {
    'Entity': 'Country'}, inplace=True)

# %%
mh_data
# Out:
#           Country Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6415     Zimbabwe  ZWE  2015
# 6416     Zimbabwe  ZWE  2016
# 6417     Zimbabwe  ZWE  2017
# 6418     Zimbabwe  ZWE  2018
# 6419     Zimbabwe  ZWE  2019
#
#       Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                              0.223206
# 1                                              0.222454
# 2                                              0.221751
# 3                                              0.220987
# 4                                              0.220183
# ...                                                 ...
# 6415                                           0.201042
# 6416                                           0.201319
# 6417                                           0.201639
# ...

# %% [markdown]
# ## Framework For Measuring Trends Across Multiple Conditions.

# %%
mh_data_long = pd.melt(mh_data, 
                       id_vars=['Country', 'Code', 'Year'],
                       var_name='Disorders',
                       value_name='Prevalence_rate'
    
)

mh_data_long
# Out:
#            Country Code  Year  \
# 0      Afghanistan  AFG  1990
# 1      Afghanistan  AFG  1991
# 2      Afghanistan  AFG  1992
# 3      Afghanistan  AFG  1993
# 4      Afghanistan  AFG  1994
# ...            ...  ...   ...
# 32095     Zimbabwe  ZWE  2015
# 32096     Zimbabwe  ZWE  2016
# 32097     Zimbabwe  ZWE  2017
# 32098     Zimbabwe  ZWE  2018
# 32099     Zimbabwe  ZWE  2019
#
#                                                Disorders  Prevalence_rate
# 0      Schizophrenia disorders (share of population) ...         0.223206
# 1      Schizophrenia disorders (share of population) ...         0.222454
# 2      Schizophrenia disorders (share of population) ...         0.221751
# 3      Schizophrenia disorders (share of population) ...         0.220987
# 4      Schizophrenia disorders (share of population) ...         0.220183
# ...                                                  ...              ...
# 32095  Eating disorders (share of population) - Sex: ...         0.095652
# ...

# %%
mh_data_long['Disorders'] = mh_data_long['Disorders'].str.extract(r'^(.*? disorders)')[0] 
mh_data_long
# Out:
#            Country Code  Year                Disorders  Prevalence_rate
# 0      Afghanistan  AFG  1990  Schizophrenia disorders         0.223206
# 1      Afghanistan  AFG  1991  Schizophrenia disorders         0.222454
# 2      Afghanistan  AFG  1992  Schizophrenia disorders         0.221751
# 3      Afghanistan  AFG  1993  Schizophrenia disorders         0.220987
# 4      Afghanistan  AFG  1994  Schizophrenia disorders         0.220183
# ...            ...  ...   ...                      ...              ...
# 32095     Zimbabwe  ZWE  2015         Eating disorders         0.095652
# 32096     Zimbabwe  ZWE  2016         Eating disorders         0.096662
# 32097     Zimbabwe  ZWE  2017         Eating disorders         0.097330
# 32098     Zimbabwe  ZWE  2018         Eating disorders         0.097909
# 32099     Zimbabwe  ZWE  2019         Eating disorders         0.098295
#
# [32100 rows x 5 columns]

# %% [markdown]
# ## Calculate Year-Over-Year Prevalence Changes

# %%
mh_data_long.sort_values(['Country', 'Code', 'Year'])
# Out:
#            Country Code  Year                Disorders  Prevalence_rate
# 0      Afghanistan  AFG  1990  Schizophrenia disorders         0.223206
# 6420   Afghanistan  AFG  1990     Depressive disorders         4.996118
# 12840  Afghanistan  AFG  1990        Anxiety disorders         4.713314
# 19260  Afghanistan  AFG  1990        Bipolar disorders         0.703023
# 25680  Afghanistan  AFG  1990         Eating disorders         0.127700
# ...            ...  ...   ...                      ...              ...
# 6419      Zimbabwe  ZWE  2019  Schizophrenia disorders         0.202482
# 12839     Zimbabwe  ZWE  2019     Depressive disorders         3.395476
# 19259     Zimbabwe  ZWE  2019        Anxiety disorders         3.137017
# 25679     Zimbabwe  ZWE  2019        Bipolar disorders         0.538580
# 32099     Zimbabwe  ZWE  2019         Eating disorders         0.098295
#
# [32100 rows x 5 columns]

# %%
mh_data_long['YoY_change'] = mh_data_long.groupby(['Country', 'Disorders'])['Prevalence_rate'].diff()

# %%
mh_data_long.pop('yoy_change')
# Out:
# 0             NaN
# 1       -0.000752
# 2       -0.000703
# 3       -0.000764
# 4       -0.000804
#            ...
# 32095    0.001044
# 32096    0.001009
# 32097    0.000668
# 32098    0.000579
# 32099    0.000387
# Name: yoy_change, Length: 32100, dtype: float64

# %%
mh_data_long
# Out:
#            Country Code  Year                Disorders  Prevalence_rate  \
# 0      Afghanistan  AFG  1990  Schizophrenia disorders         0.223206
# 1      Afghanistan  AFG  1991  Schizophrenia disorders         0.222454
# 2      Afghanistan  AFG  1992  Schizophrenia disorders         0.221751
# 3      Afghanistan  AFG  1993  Schizophrenia disorders         0.220987
# 4      Afghanistan  AFG  1994  Schizophrenia disorders         0.220183
# ...            ...  ...   ...                      ...              ...
# 32095     Zimbabwe  ZWE  2015         Eating disorders         0.095652
# 32096     Zimbabwe  ZWE  2016         Eating disorders         0.096662
# 32097     Zimbabwe  ZWE  2017         Eating disorders         0.097330
# 32098     Zimbabwe  ZWE  2018         Eating disorders         0.097909
# 32099     Zimbabwe  ZWE  2019         Eating disorders         0.098295
#
#        YoY_change
# 0             NaN
# 1       -0.000752
# 2       -0.000703
# 3       -0.000764
# ...

# %%
mh_data_long=mh_data_long.fillna(0)
mh_data_long
# Out:
#            Country Code  Year                Disorders  Prevalence_rate  \
# 0      Afghanistan  AFG  1990  Schizophrenia disorders         0.223206
# 1      Afghanistan  AFG  1991  Schizophrenia disorders         0.222454
# 2      Afghanistan  AFG  1992  Schizophrenia disorders         0.221751
# 3      Afghanistan  AFG  1993  Schizophrenia disorders         0.220987
# 4      Afghanistan  AFG  1994  Schizophrenia disorders         0.220183
# ...            ...  ...   ...                      ...              ...
# 32095     Zimbabwe  ZWE  2015         Eating disorders         0.095652
# 32096     Zimbabwe  ZWE  2016         Eating disorders         0.096662
# 32097     Zimbabwe  ZWE  2017         Eating disorders         0.097330
# 32098     Zimbabwe  ZWE  2018         Eating disorders         0.097909
# 32099     Zimbabwe  ZWE  2019         Eating disorders         0.098295
#
#        YoY_change
# 0        0.000000
# 1       -0.000752
# 2       -0.000703
# 3       -0.000764
# ...

# %%
mh_data_long.tail()
# Out:
#         Country Code  Year         Disorders  Prevalence_rate  YoY_change
# 32095  Zimbabwe  ZWE  2015  Eating disorders         0.095652    0.001044
# 32096  Zimbabwe  ZWE  2016  Eating disorders         0.096662    0.001009
# 32097  Zimbabwe  ZWE  2017  Eating disorders         0.097330    0.000668
# 32098  Zimbabwe  ZWE  2018  Eating disorders         0.097909    0.000579
# 32099  Zimbabwe  ZWE  2019  Eating disorders         0.098295    0.000387

# %%
mh_data_long
# Out:
#            Country Code  Year                Disorders  Prevalence_rate  \
# 0      Afghanistan  AFG  1990  Schizophrenia disorders         0.223206
# 1      Afghanistan  AFG  1991  Schizophrenia disorders         0.222454
# 2      Afghanistan  AFG  1992  Schizophrenia disorders         0.221751
# 3      Afghanistan  AFG  1993  Schizophrenia disorders         0.220987
# 4      Afghanistan  AFG  1994  Schizophrenia disorders         0.220183
# ...            ...  ...   ...                      ...              ...
# 32095     Zimbabwe  ZWE  2015         Eating disorders         0.095652
# 32096     Zimbabwe  ZWE  2016         Eating disorders         0.096662
# 32097     Zimbabwe  ZWE  2017         Eating disorders         0.097330
# 32098     Zimbabwe  ZWE  2018         Eating disorders         0.097909
# 32099     Zimbabwe  ZWE  2019         Eating disorders         0.098295
#
#        YoY_change
# 0        0.000000
# 1       -0.000752
# 2       -0.000703
# 3       -0.000764
# ...

# %% [markdown]
# ## Creating Visual Display For Year-over-Year Prevalence Changes

# %%
average_yoy = mh_data_long.groupby(['Disorders', 'Year'])['YoY_change'].mean().reset_index()

# %%
average_yoy
# Out:
#                    Disorders  Year  YoY_change
# 0          Anxiety disorders  1990    0.000000
# 1          Anxiety disorders  1991    0.000185
# 2          Anxiety disorders  1992    0.000306
# 3          Anxiety disorders  1993    0.000296
# 4          Anxiety disorders  1994    0.000366
# ..                       ...   ...         ...
# 145  Schizophrenia disorders  2015    0.000110
# 146  Schizophrenia disorders  2016    0.000143
# 147  Schizophrenia disorders  2017    0.000130
# 148  Schizophrenia disorders  2018   -0.000006
# 149  Schizophrenia disorders  2019   -0.000089
#
# [150 rows x 3 columns]

# %%
mh_data_long
# Out:
#            Country Code  Year                Disorders  Prevalence_rate  \
# 0      Afghanistan  AFG  1990  Schizophrenia disorders         0.223206
# 1      Afghanistan  AFG  1991  Schizophrenia disorders         0.222454
# 2      Afghanistan  AFG  1992  Schizophrenia disorders         0.221751
# 3      Afghanistan  AFG  1993  Schizophrenia disorders         0.220987
# 4      Afghanistan  AFG  1994  Schizophrenia disorders         0.220183
# ...            ...  ...   ...                      ...              ...
# 32095     Zimbabwe  ZWE  2015         Eating disorders         0.095652
# 32096     Zimbabwe  ZWE  2016         Eating disorders         0.096662
# 32097     Zimbabwe  ZWE  2017         Eating disorders         0.097330
# 32098     Zimbabwe  ZWE  2018         Eating disorders         0.097909
# 32099     Zimbabwe  ZWE  2019         Eating disorders         0.098295
#
#        YoY_change
# 0        0.000000
# 1       -0.000752
# 2       -0.000703
# 3       -0.000764
# ...

# %%
conditions = average_yoy['Disorders'].unique()
conditions
# Out:
# array(['Anxiety disorders', 'Bipolar disorders', 'Depressive disorders',
#        'Eating disorders', 'Schizophrenia disorders'], dtype=object)

# %%
plt.figure(figsize=(12,6))

for c in conditions:
    subset = average_yoy[average_yoy['Disorders'] == c]
    plt.plot(subset['Year'], subset['YoY_change'], label = c)

plt.title('Average YoY Disorder Prevalence vs Year')
plt.legend(loc = 'lower left')
plt.xlabel('Year')
plt.ylabel('Average YoY Change')
plt.show()

plt.savefig('Average_YoY_Disorder_Prevalence_vs_Year.png')

# %% [markdown]
# ## Cohort Analysis Tracking

# %%
base_year = mh_data_long['Year'].min()
base_year
# Out:
# 1990

# %%
mh_data_base = mh_data_long[mh_data_long['Year'] == base_year].copy()
mh_data_base
# Out:
#                   Country      Code  Year                Disorders  \
# 0             Afghanistan       AFG  1990  Schizophrenia disorders
# 30      Africa (IHME GBD)         0  1990  Schizophrenia disorders
# 60                Albania       ALB  1990  Schizophrenia disorders
# 90                Algeria       DZA  1990  Schizophrenia disorders
# 120    America (IHME GBD)         0  1990  Schizophrenia disorders
# ...                   ...       ...   ...                      ...
# 31950             Vietnam       VNM  1990         Eating disorders
# 31980               World  OWID_WRL  1990         Eating disorders
# 32010               Yemen       YEM  1990         Eating disorders
# 32040              Zambia       ZMB  1990         Eating disorders
# 32070            Zimbabwe       ZWE  1990         Eating disorders
#
#        Prevalence_rate  YoY_change
# 0             0.223206         0.0
# 30            0.219527         0.0
# 60            0.281197         0.0
# ...

# %%
mh_data_base['Quartile'] = mh_data_base.groupby('Disorders')['Prevalence_rate'].transform(lambda x: (pd.qcut(x, 4, labels=[1,2,3,4])))
mh_data_base
# Out:
#                   Country      Code  Year                Disorders  \
# 0             Afghanistan       AFG  1990  Schizophrenia disorders
# 30      Africa (IHME GBD)         0  1990  Schizophrenia disorders
# 60                Albania       ALB  1990  Schizophrenia disorders
# 90                Algeria       DZA  1990  Schizophrenia disorders
# 120    America (IHME GBD)         0  1990  Schizophrenia disorders
# ...                   ...       ...   ...                      ...
# 31950             Vietnam       VNM  1990         Eating disorders
# 31980               World  OWID_WRL  1990         Eating disorders
# 32010               Yemen       YEM  1990         Eating disorders
# 32040              Zambia       ZMB  1990         Eating disorders
# 32070            Zimbabwe       ZWE  1990         Eating disorders
#
#        Prevalence_rate  YoY_change Quartile
# 0             0.223206         0.0        1
# 30            0.219527         0.0        1
# ...

# %%
mh_data_long = mh_data_long.merge(
    mh_data_base[['Country','Disorders', 'Quartile']],
    on = ['Country','Disorders'],
    how = 'left'
)
mh_data_long
# Out:
#            Country Code  Year                Disorders  Prevalence_rate  \
# 0      Afghanistan  AFG  1990  Schizophrenia disorders         0.223206
# 1      Afghanistan  AFG  1991  Schizophrenia disorders         0.222454
# 2      Afghanistan  AFG  1992  Schizophrenia disorders         0.221751
# 3      Afghanistan  AFG  1993  Schizophrenia disorders         0.220987
# 4      Afghanistan  AFG  1994  Schizophrenia disorders         0.220183
# ...            ...  ...   ...                      ...              ...
# 32095     Zimbabwe  ZWE  2015         Eating disorders         0.095652
# 32096     Zimbabwe  ZWE  2016         Eating disorders         0.096662
# 32097     Zimbabwe  ZWE  2017         Eating disorders         0.097330
# 32098     Zimbabwe  ZWE  2018         Eating disorders         0.097909
# 32099     Zimbabwe  ZWE  2019         Eating disorders         0.098295
#
#        YoY_change Quartile
# 0        0.000000        1
# 1       -0.000752        1
# ...

# %%
mh_data_long['Quartile'] = mh_data_long['Quartile'].astype(float)
mh_data_long
# Out:
#            Country Code  Year                Disorders  Prevalence_rate  \
# 0      Afghanistan  AFG  1990  Schizophrenia disorders         0.223206
# 1      Afghanistan  AFG  1991  Schizophrenia disorders         0.222454
# 2      Afghanistan  AFG  1992  Schizophrenia disorders         0.221751
# 3      Afghanistan  AFG  1993  Schizophrenia disorders         0.220987
# 4      Afghanistan  AFG  1994  Schizophrenia disorders         0.220183
# ...            ...  ...   ...                      ...              ...
# 32095     Zimbabwe  ZWE  2015         Eating disorders         0.095652
# 32096     Zimbabwe  ZWE  2016         Eating disorders         0.096662
# 32097     Zimbabwe  ZWE  2017         Eating disorders         0.097330
# 32098     Zimbabwe  ZWE  2018         Eating disorders         0.097909
# 32099     Zimbabwe  ZWE  2019         Eating disorders         0.098295
#
#        YoY_change  Quartile
# 0        0.000000       1.0
# 1       -0.000752       1.0
# ...

# %%
average_quartile = mh_data_long.groupby(['Disorders','Quartile', 'Year'])['Prevalence_rate'].mean().reset_index()
average_quartile
# Out:
#                    Disorders  Quartile  Year  Prevalence_rate
# 0          Anxiety disorders       1.0  1990         2.983504
# 1          Anxiety disorders       1.0  1991         2.982307
# 2          Anxiety disorders       1.0  1992         2.981312
# 3          Anxiety disorders       1.0  1993         2.980472
# 4          Anxiety disorders       1.0  1994         2.979756
# ..                       ...       ...   ...              ...
# 595  Schizophrenia disorders       4.0  2015         0.310875
# 596  Schizophrenia disorders       4.0  2016         0.310870
# 597  Schizophrenia disorders       4.0  2017         0.310874
# 598  Schizophrenia disorders       4.0  2018         0.310834
# 599  Schizophrenia disorders       4.0  2019         0.310773
#
# [600 rows x 4 columns]

# %%
disorder_to_plot = 'Schizophrenia disorders'

# %%
plot_data = average_quartile[average_quartile['Disorders'] == disorder_to_plot]
plot_data
# Out:
#                    Disorders  Quartile  Year  Prevalence_rate
# 480  Schizophrenia disorders       1.0  1990         0.212834
# 481  Schizophrenia disorders       1.0  1991         0.212901
# 482  Schizophrenia disorders       1.0  1992         0.212948
# 483  Schizophrenia disorders       1.0  1993         0.212974
# 484  Schizophrenia disorders       1.0  1994         0.212974
# ..                       ...       ...   ...              ...
# 595  Schizophrenia disorders       4.0  2015         0.310875
# 596  Schizophrenia disorders       4.0  2016         0.310870
# 597  Schizophrenia disorders       4.0  2017         0.310874
# 598  Schizophrenia disorders       4.0  2018         0.310834
# 599  Schizophrenia disorders       4.0  2019         0.310773
#
# [120 rows x 4 columns]

# %%
plt.figure(figsize=(12,6))

for q in sorted(plot_data['Quartile'].unique()):
    schiz_set = plot_data[plot_data['Quartile'] == q]
    plt.plot(schiz_set['Year'], schiz_set['Prevalence_rate'], marker = "s", label = f'Quartile {int(q)}')

plt.title('Prevalence Over Time by Initial Quartile')
plt.xlabel('Year')
plt.legend()
plt.ylabel('Prevalence Rate')
plt.show()
